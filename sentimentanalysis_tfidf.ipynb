# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

# %%
df = pd.read_csv("final2.csv", sep=',')

# %%
df.isnull().sum()
# Out:
# label      0
# stemmed    1
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# label      0
# stemmed    0
# dtype: int64

# %%
df.head()
# Out:
#    label                                            stemmed
# 0      0  jalan jatibarupolisi tidak bisa gertak gubernu...
# 1      0  cewek lho kayak rasain sibuk jaga rasain sakit...
# 2      1  kepingin gudeg mbarek bu hj amad foto google s...
# 3      0  jalan jatibarubagian wilayah tn abangpengatura...
# 4      1  sharing alam saja kemarin jam batalin tiket st...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfid = TfidfVectorizer(max_features=5000)

# %%
X = tfid.fit_transform(df['stemmed'])
y = df['label']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.model_selection import cross_validate

# %%
from sklearn.metrics import make_scorer, accuracy_score, f1_score, precision_score, recall_score

scoring = {
    'accuracy': make_scorer(accuracy_score),
    'f1': make_scorer(f1_score, average='weighted'),
    'precision': make_scorer(precision_score, average='weighted'),
    'recall': make_scorer(recall_score, average='weighted')
}

# %%
# logistic regression
results = cross_validate(LogisticRegression(), X, y, cv=10, scoring=scoring)

mean_accuracy = np.mean(results['test_accuracy'])
mean_f1 = np.mean(results['test_f1'])
mean_precision = np.mean(results['test_precision'])
mean_recall = np.mean(results['test_recall'])

print(f"Accuracy: {mean_accuracy}")
print(f"F1 Score: {mean_f1}")
print(f"Precision: {mean_precision}")
print(f"Recall: {mean_recall}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# svm

results = cross_validate(SVC(), X, y, cv=10, scoring=scoring)

mean_accuracy = np.mean(results['test_accuracy'])
mean_f1 = np.mean(results['test_f1'])
mean_precision = np.mean(results['test_precision'])
mean_recall = np.mean(results['test_recall'])

print(f"Accuracy: {mean_accuracy}")
print(f"F1 Score: {mean_f1}")
print(f"Precision: {mean_precision}")
print(f"Recall: {mean_recall}")
# Out:
# Accuracy: 0.7143017158501687
# F1 Score: 0.7099780531475518
# Precision: 0.7320962752532572
# Recall: 0.7143017158501687

# %%
# random forest
results = cross_validate(RandomForestClassifier(), X, y, cv=10, scoring=scoring)

mean_accuracy = np.mean(results['test_accuracy'])
mean_f1 = np.mean(results['test_f1'])
mean_precision = np.mean(results['test_precision'])
mean_recall = np.mean(results['test_recall'])

print(f"Accuracy: {mean_accuracy}")
print(f"F1 Score: {mean_f1}")
print(f"Precision: {mean_precision}")
print(f"Recall: {mean_recall}")
# Out:
# Accuracy: 0.6972312468901483
# F1 Score: 0.6881280046845853
# Precision: 0.7162393416843643
# Recall: 0.6972312468901483

# %%
# decision tree
results = cross_validate(DecisionTreeClassifier(), X, y, cv=10, scoring=scoring)

mean_accuracy = np.mean(results['test_accuracy'])
mean_f1 = np.mean(results['test_f1'])
mean_precision = np.mean(results['test_precision'])
mean_recall = np.mean(results['test_recall'])

print(f"Accuracy: {mean_accuracy}")
print(f"F1 Score: {mean_f1}")
print(f"Precision: {mean_precision}")
print(f"Recall: {mean_recall}")
# Out:
# Accuracy: 0.6075802707625526
# F1 Score: 0.6023359895661953
# Precision: 0.6131144381365898
# Recall: 0.6075802707625526

# %%
# knn


results = cross_validate(KNeighborsClassifier(n_neighbors=25), X, y, cv=10, scoring=scoring)

mean_accuracy = np.mean(results['test_accuracy'])
mean_f1 = np.mean(results['test_f1'])
mean_precision = np.mean(results['test_precision'])
mean_recall = np.mean(results['test_recall'])

print(f"Accuracy: {mean_accuracy}")
print(f"F1 Score: {mean_f1}")
print(f"Precision: {mean_precision}")
print(f"Recall: {mean_recall}")
# Out:
# Accuracy: 0.6311372432472593
# F1 Score: 0.6269682875517214
# Precision: 0.6547039529105925
# Recall: 0.6311372432472593

# %%
# mlp
results = cross_validate(MLPClassifier(), X, y, cv=10, scoring=scoring)

mean_accuracy = np.mean(results['test_accuracy'])
mean_f1 = np.mean(results['test_f1'])
mean_precision = np.mean(results['test_precision'])
mean_recall = np.mean(results['test_recall'])

print(f"Accuracy: {mean_accuracy}")
print(f"F1 Score: {mean_f1}")
print(f"Precision: {mean_precision}")
print(f"Recall: {mean_recall}")
# Out:
# Accuracy: 0.5980125092029098
# F1 Score: 0.5954101191807777
# Precision: 0.6031118675367245
# Recall: 0.5980125092029098

# %%
# Logistic Regression

clf = GridSearchCV(LogisticRegression(), {
    "C" : [0.01, 0.1, 1, 10],
}, cv=10, return_train_score=False)

clf.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-49678edfb1a6> in <cell line: 3>()
#       1 # Logistic Regression
#       2
# ----> 3 clf = GridSearchCV(LogisticRegression(), cv=10, return_train_score=False)
#       4
#       5 clf.fit(X, y)
#
# TypeError: GridSearchCV.__init__() missing 1 required positional argument: 'param_grid'

# %%
logistic_regression_results = pd.DataFrame(clf.cv_results_)
logistic_regression_results[["params", 'mean_test_score', 'rank_test_score']]
# Out:
#         params  mean_test_score  rank_test_score
# 0  {'C': 0.01}         0.500003                4
# 1   {'C': 0.1}         0.681745                3
# 2     {'C': 1}         0.718547                1
# 3    {'C': 10}         0.693503                2

# %%
# SVM

clf = GridSearchCV(SVC(), {
    'C': [0.01, 0.1, 1, 10],
    'kernel': ['rbf', 'linear']
}, cv=10, return_train_score=False)

clf.fit(X, y)
#0.634852
# Out:
# GridSearchCV(cv=10, estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 1, 10], 'kernel': ['rbf', 'linear']})

# %%
svm_results = pd.DataFrame(clf.cv_results_)
svm_results[["params", 'mean_test_score', 'rank_test_score']]
# Out:
#                             params  mean_test_score  rank_test_score
# 0     {'C': 0.01, 'kernel': 'rbf'}         0.240743                8
# 1  {'C': 0.01, 'kernel': 'linear'}         0.323847                7
# 2      {'C': 0.1, 'kernel': 'rbf'}         0.498734                6
# 3   {'C': 0.1, 'kernel': 'linear'}         0.654588                5
# 4        {'C': 1, 'kernel': 'rbf'}         0.714302                1
# 5     {'C': 1, 'kernel': 'linear'}         0.706980                3
# 6       {'C': 10, 'kernel': 'rbf'}         0.710057                2
# 7    {'C': 10, 'kernel': 'linear'}         0.659768                4

# %%
# Random Forest

clf = GridSearchCV(RandomForestClassifier(), {
    "n_estimators" : [100, 500, 1000],
    "criterion" : ["gini", 'entropy']
}, cv=10, return_train_score=False)

clf.fit(X, y)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'n_estimators': [100, 500, 1000]})

# %%
random_forest_results = pd.DataFrame(clf.cv_results_)
random_forest_results[["params", 'mean_test_score', 'rank_test_score']]
# Out:
#                                            params  mean_test_score  \
# 0      {'criterion': 'gini', 'n_estimators': 100}         0.699990
# 1      {'criterion': 'gini', 'n_estimators': 500}         0.701157
# 2     {'criterion': 'gini', 'n_estimators': 1000}         0.702640
# 3   {'criterion': 'entropy', 'n_estimators': 100}         0.695428
# 4   {'criterion': 'entropy', 'n_estimators': 500}         0.699248
# 5  {'criterion': 'entropy', 'n_estimators': 1000}         0.700838
#
#    rank_test_score
# 0                4
# 1                2
# 2                1
# 3                6
# 4                5
# 5                3

# %%
# Decision Tree

clf = GridSearchCV(DecisionTreeClassifier(), {
    "criterion" : ["gini", 'entropy'],
    "splitter" : ['best', 'random']
}, cv=10, return_train_score=False)

clf.fit(X, y)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'splitter': ['best', 'random']})

# %%
decision_tree_results = pd.DataFrame(clf.cv_results_)
decision_tree_results[["params", 'mean_test_score', 'rank_test_score']]
# Out:
#                                            params  mean_test_score  \
# 0       {'criterion': 'gini', 'splitter': 'best'}         0.608003
# 1     {'criterion': 'gini', 'splitter': 'random'}         0.625300
# 2    {'criterion': 'entropy', 'splitter': 'best'}         0.595589
# 3  {'criterion': 'entropy', 'splitter': 'random'}         0.609381
#
#    rank_test_score
# 0                3
# 1                1
# 2                4
# 3                2

# %%
# K Nearest Neighbors

clf = GridSearchCV(KNeighborsClassifier(), {
    "n_neighbors" : [100, 250, 500, 750, 1000]
}, cv=10, return_train_score=False)

clf.fit(X, y)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [100, 250, 500, 750, 1000]})

# %%
knn_results = pd.DataFrame(clf.cv_results_)
knn_results[["params", 'mean_test_score', 'rank_test_score']]
# Out:
#                   params  mean_test_score  rank_test_score
# 0   {'n_neighbors': 100}         0.678348                2
# 1   {'n_neighbors': 250}         0.680258                1
# 2   {'n_neighbors': 500}         0.663816                3
# 3   {'n_neighbors': 750}         0.649281                4
# 4  {'n_neighbors': 1000}         0.630819                5

# %%
# Neural Network (Multi Layer Perceptron)

clf = GridSearchCV(MLPClassifier(), {
    'activation': ['tanh', 'relu'],
    'learning_rate': ['constant','adaptive'],
}, cv=10, return_train_score=False)

clf.fit(X, y)
# Out:
# GridSearchCV(cv=10, estimator=MLPClassifier(),
#              param_grid={'activation': ['tanh', 'relu'],
#                          'learning_rate': ['constant', 'adaptive']})

# %%
mlp_results = pd.DataFrame(clf.cv_results_)
mlp_results[["params", 'mean_test_score', 'rank_test_score']]
# Out:
#                                               params  mean_test_score  \
# 0  {'activation': 'tanh', 'learning_rate': 'const...         0.550901
# 1  {'activation': 'tanh', 'learning_rate': 'adapt...         0.549521
# 2  {'activation': 'relu', 'learning_rate': 'const...         0.598967
# 3  {'activation': 'relu', 'learning_rate': 'adapt...         0.595574
#
#    rank_test_score
# 0                3
# 1                4
# 2                1
# 3                2
